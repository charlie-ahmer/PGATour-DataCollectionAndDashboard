# %% [markdown]
# # PGA Tour Web Scraping
# ### *Data is obtained using PGATour.com's GraphQL API*
#
#
# Initially, when I attempted to scrape data from pgatour.com using traditional web scraping techniques with BeautifulSoup, I encountered a roadblock. It became evident that pgatour.com utilizes GraphQL, a query language for APIs, to handle its data. This meant that directly scraping the website's HTML structure wouldn't provide the desired results. Realizing the need to adapt, I learned about GraphQL and how to effectively query the data using python. With this knowledge and understanding, I implemented GraphQL queries to retrieve the specific data I required from pgatour.com. This transition allowed me to efficiently extract the desired information from the website, enabling me to proceed with my data analysis and exploration.
#
#
# ### Tasks
# This Jupyter Notebook contains code for retrieving and analyzing PGA Tour data using the GraphQL API. The code performs the following tasks:
#
# 1. Imports the necessary packages and sets up the API endpoint.
# 2. Sends a GraphQL introspection query to retrieve the schema.
# 3. Saves the GraphQL schema as a JSON file.
# 4. Defines functions to retrieve player statistics, player information, and tournament winners.
# 5. Retrieves player statistics and information for multiple years.
# 6. Merges the data into a single DataFrame.
# 7. Performs data cleaning and type conversion.
# 8. Saves the final DataFrame as a CSV file.
#
# ### Code Explanation
#
# The code is divided into several sections:
#
# 1. Importing Packages: Importing the required packages, including `requests`, `json`, and `pandas`.
#
# 2. API Configuration: Defining the API endpoint URL and the `X_API_KEY` token.
#
# 3. GraphQL Introspection Query: Defining the GraphQL introspection query to retrieve the schema.
#
# 4. Retrieving the Schema: Sending the introspection query to the server and saving the schema as a JSON file.
#
# 5. Function Definitions: Defining helper functions to retrieve player statistics, player information, and tournament winners.
#
# 6. Data Retrieval and Processing: Looping through the desired years and retrieving player statistics, player information, and tournament winners. Merging the data into a single DataFrame.
#
# 7. Data Cleaning and Type Conversion: Performing data cleaning and converting columns to their appropriate data types.
#
# 8. Saving the Data: Saving the final DataFrame as a CSV file.

# %%
##### Import all required packages #####
import requests
#import graphql
import json
from numpy import NaN
import pandas as pd

# %%
# in the requests header seems to be a constant token ('x-api-key') that is needed
# found in devtools
X_API_KEY = "da2-gsrx5bibzbb4njvhl7t37wqyl4"

url = "https://orchestrator.pgatour.com/graphql"

# GraphQL introspection query
introspection_query = """
    query IntrospectionQuery {
        __schema {
            queryType {
                name
            }
            mutationType {
                name
            }
            subscriptionType {
                name
            }
            types {
                ...FullType
            }
            directives {
                name
                description
                locations
                args {
                    ...InputValue
                }
            }
        }
    }

    fragment FullType on __Type {
        kind
        name
        description
        fields(includeDeprecated: true) {
            name
            description
            args {
                ...InputValue
            }
            type {
                ...TypeRef
            }
            isDeprecated
            deprecationReason
        }
        inputFields {
            ...InputValue
        }
        interfaces {
            ...TypeRef
        }
        enumValues(includeDeprecated: true) {
            name
            description
            isDeprecated
            deprecationReason
        }
        possibleTypes {
            ...TypeRef
        }
    }

    fragment InputValue on __InputValue {
        name
        description
        type {
            ...TypeRef
        }
        defaultValue
    }

    fragment TypeRef on __Type {
        kind
        name
        ofType {
            kind
            name
            ofType {
                kind
                name
                ofType {
                    kind
                    name
                    ofType {
                        kind
                        name
                        ofType {
                            kind
                            name
                            ofType {
                                kind
                                name
                            }
                        }
                    }
                }
            }
        }
    }
"""

# Send the introspection query to the server
response = requests.post(
    url, json={"query": introspection_query}, headers={"x-api-key": X_API_KEY}
)

# Print the response (GraphQL schema)
json_schema = response.json()

with open("graphql_schema.json", "w") as f:
    # Use the `json.dump()` method to write the data to the file
    json.dump(json_schema, f, indent=4)

# %%
# Stat IDs and Stat Description used for queries
# This will be the features in final data set
stats = {
    "120": "ScoringAvg",
    "156": "BirdieAvg",
    "101": "DrivingDistance",
    "129": "TotalDriving",
    "103": "GIR%",
    "130": "Scrambling",
    "02675": "SG_Total",
    "02568": "SG_ApproachGreen",
    "02564": "SG_Putting",
    "02567": "SG_OffTee",
    "02569": "SG_AroundGreen",
    "02674": "SG_TeeToGreen",
    "02394": "FedExCupPoints",
    "138": "Top10Finishes",
    "186": "WorldRank",
    "109": "Money"
}

# %%
# some functions containing queries used to extract data from PGATour.com
# Data Structures varied, therefore multiple functions/queries were needed

def get_df(YEAR, STAT_ID, DESCR):
    X_API_KEY = "da2-gsrx5bibzbb4njvhl7t37wqyl4"
    req = {
        "operationName": "StatDetails",
        "variables": {
            "tourCode": "R",
            "statId": STAT_ID,
            "year": YEAR,
            "eventQuery": None,
        },
        "query": """query StatDetails($tourCode: TourCode!, $statId: String!, $year: Int, $eventQuery: StatDetailEventQuery) {
  statDetails(
    tourCode: $tourCode
    statId: $statId
    year: $year
    eventQuery: $eventQuery
  ) {
    tourCode
    year
    displaySeason
    statId
    statType
    tournamentPills {
      tournamentId
      displayName
    }
    yearPills {
      year
      displaySeason
    }
    statTitle
    statDescription
    tourAvg
    lastProcessed
    statHeaders
    statCategories {
      category
      displayName
      subCategories {
        displayName
        stats {
          statId
          statTitle
        }
      }
    }
    rows {
      ... on StatDetailsPlayer {
        __typename
        playerId
        playerName
        country
        countryFlag
        rank
        rankDiff
        rankChangeTendency
        stats {
          statName
          statValue
          color
        }
      }
      ... on StatDetailTourAvg {
        __typename
        displayName
        value
      }
    }
    sponsorLogo
    }
    } 
    """,
    }

    # post the request
    page = requests.post(
        url,
        json=req,
        headers={"x-api-key": X_API_KEY},
    )
    # get the data
    data = page.json()["data"]["statDetails"]["rows"]

    # filter out items, thats __typename is not "StatDetailsPlayer" like
    # data contains -> "__typename": "StatDetailTourAvg", remove the tour average value
    data = filter(lambda item: item.get("__typename", NaN) == "StatDetailsPlayer", data)

    # format to a table that is in the webpage
    
    table = map(
        lambda item: {
            # "RANK": item["rank"],
            "PID" : item["playerId"],
            "PLAYER": item["playerName"],
            DESCR: item["stats"][0]["statValue"],
        },
        data,
    )

    # convert the dataframe
    s = pd.DataFrame(table)

    return s

def get_players():
    url = "https://orchestrator.pgatour.com/graphql"

    X_API_KEY = "da2-gsrx5bibzbb4njvhl7t37wqyl4"
    req = {
    "operationName": "PlayerDirectory",
    "variables": {
        "tourCode": "R"
    },
    "query": """query PlayerDirectory($tourCode: TourCode!, $active: Boolean) {  playerDirectory(tourCode: $tourCode, active: $active) {    tourCode    players {      id      isActive      firstName      lastName      shortName      displayName      alphaSort      country      countryFlag      headshot      playerBio {        id        age        education        turnedPro      }    }  }}
    """,
    }

    # post the request
    page = requests.post(
    url,
    json=req,
    headers={"x-api-key": X_API_KEY},
    )
    # get the data
    # print(page.json())
    data = page.json()["data"]["playerDirectory"]["players"]

    # filter out items, thats __typename is not "StatDetailsPlayer" like
    # data contains -> "__typename": "StatDetailTourAvg", remove the tour average value
    # data = filter(lambda item: item.get("__typename", NaN) == "StatDetailsPlayer", data)

    # format to a table that is in the webpage

    table = map(
    lambda item: {
        # "RANK": item["rank"],
        "PID" : item["id"],
        "PLAYER": item['displayName'],
        "Country": item["countryFlag"],
    },
    data,
    )

    # convert the dataframe
    s = pd.DataFrame(table)

    return s

def get_wins(YEAR):
    X_API_KEY = "da2-gsrx5bibzbb4njvhl7t37wqyl4"
    req = {
    "operationName": "TourCupSplit",
    "variables": {
        "id": "fedex",
        "tourCode": "R",
        "year": YEAR
    },
    "query": """query TourCupSplit($tourCode: TourCode!, $id: String, $year: Int, $eventQuery: StatDetailEventQuery) {
      tourCupSplit(tourCode: $tourCode, id: $id, year: $year, eventQuery: $eventQuery) {
        id
        title
        projectedTitle
        projectedLive
        season
        description
        detailCopy
        logo
        options
        fixedHeaders
        columnHeaders
        rankingsHeader
        message
        projectedPlayers {
          ...Player
          ...InfoRow
        }
        officialPlayers {
          ...Player
          ...InfoRow
        }
        tournamentPills {
          tournamentId
          displayName
        }
        yearPills {
          year
          displaySeason
        }
        winner {
          id
          rank
          firstName
          lastName
          displayName
          shortName
          countryFlag
          country
          earnings
          totals {
            label
            value
          }
        }
      }
    }

    fragment Player on TourCupCombinedPlayer {
      __typename
      id
      firstName
      lastName
      displayName
      shortName
      countryFlag
      country
      rankingData {
        projected
        official
        event
        movement
        movementAmount
        logo
        logoDark
      }
      pointData {
        projected
        official
        event
        movement
        movementAmount
        logo
        logoDark
      }
      projectedSort
      officialSort
      thisWeekRank
      previousWeekRank
      columnData
    }

    fragment InfoRow on TourCupCombinedInfo {
      logo
      logoDark
      text
      sortValue
    }
    """,
    }

    # post the request
    page = requests.post(
    url,
    json=req,
    headers={"x-api-key": X_API_KEY},
    )
    # get the data
    #print(page.json())
    data = page.json()["data"]["tourCupSplit"]["officialPlayers"]

    # filter out items, thats __typename is not "StatDetailsPlayer" like
    # data contains -> "__typename": "StatDetailTourAvg", remove the tour average value
    # data = filter(lambda item: item.get("__typename", NaN) == "StatDetailsPlayer", data)

    # format to a table that is in the webpage

    table = map(
    lambda item: {
        # "RANK": item["rank"],
        "PID" : item["id"],
        "PLAYER": item["displayName"],
        "#Wins": item["columnData"][2]
    },
    data,
    )

    # convert the dataframe
    s = pd.DataFrame(table)

    return s

# %%
# Loop through each year and continually merge the data frame to store all data from 2007-2022
years = [year for year in range(2007, 2023)]
dfs = []

players = get_players()
#print(players.head())
for year in years:
    df = pd.DataFrame()
    for key in stats:
        if len(df) == 0:
            df = get_df(year, key, stats[key])
            #print(df)
        else:
            curr = get_df(year, key, stats[key])
            #print(df)
            print(curr)
            df = pd.merge(df, curr, on=["PID","PLAYER"])
    df['Year'] = year  # Add a 'year' column with the current year
    wins = get_wins(year)

    df = pd.merge(df, players, on=["PID","PLAYER"])
    df = pd.merge(df,wins,on=["PID","PLAYER"])

    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)

combined_df.head()
# Out:
#        PID               PLAYER BirdieAvg
# 0    08793          Tiger Woods      4.03
# 1    21731     Freddie Jacobson      4.01
# 2    24925        Jonathan Byrd      3.89
# 3    12660      Jesper Parnevik      3.88
# 4    01161    Mark Calcavecchia      3.87
# ..     ...                  ...       ...
# 191  06373  José María Olazábal      2.82
# 192  01132          Mark Brooks      2.72
# 193  01157            Tom Byrum      2.70
# 194  02036         Jim Rutledge      2.66
# 195  01473        Todd Hamilton      2.63
#
# [196 rows x 3 columns]
#        PID             PLAYER DrivingDistance
# 0    25804       Bubba Watson           315.2
# 1    01249          John Daly           312.9
# 2    27141        J.B. Holmes           312.6
# 3    24358    Robert Garrigus           310.5
# 4    24980  Scott Gutschewski           306.1
# ..     ...                ...             ...
# 191  06643        Paul Goydos           272.4
# 192  01381          Fred Funk           271.8
# 193  19846          Brian Gay           270.0
# 194  20623        Gavin Coles           268.3
# 195  01928        Corey Pavin           265.3
#
# [196 rows x 3 columns]
#        PID               PLAYER TotalDriving
# 0    23349       Charles Warren           59
# 1    20574        Mathew Goggin           70
# 2    24781         Hunter Mahan           73
# 3    10425       Jay Williamson           84
# 4    01945          Kenny Perry          104
# ..     ...                  ...          ...
# 191  23613         Rich Barcelo          296
# 192  21350          Ryuji Imada          315
# 193  06251        Chris DiMarco          317
# 194  02104          Jeff Sluman          325
# 195  06373  José María Olazábal          382
#
# [196 rows x 3 columns]
#        PID               PLAYER   GIR%
# 0    08793          Tiger Woods  71.02
# 1    20645          John Senden  70.33
# 2    20105            Jeff Gove  70.17
# 3    12652      Cameron Beckman  69.87
# 4    01035     Tommy Armour III  69.84
# ..     ...                  ...    ...
# 191  06643          Paul Goydos  59.42
# 192  26360      Bubba Dickerson  59.34
# 193  20157        Retief Goosen  58.91
# 194  01473        Todd Hamilton  56.94
# 195  06373  José María Olazábal  54.33
#
# [196 rows x 3 columns]
#        PID            PLAYER Scrambling
# 0    20127       Chris Riley      65.33
# 1    23621    Rory Sabbatini      63.92
# 2    25396          Kevin Na      63.65
# 3    23135         Tim Clark      63.60
# 4    23108       Matt Kuchar      63.41
# ..     ...               ...        ...
# 191  23638  Brendon de Jonge      50.43
# 192  27702      Matt Hendrix      49.87
# 193  28486    Michael Putnam      49.08
# 194  01249         John Daly      48.91
# 195  23322   Brett Wetterich      48.86
#
# [196 rows x 3 columns]
#        PID           PLAYER SG_Total
# 0    08793      Tiger Woods    3.092
# 1    01810   Phil Mickelson    1.597
# 2    06522        Ernie Els    1.578
# 3    06527   Steve Stricker    1.486
# 4    21209    Sergio Garcia    1.461
# ..     ...              ...      ...
# 191  27702     Matt Hendrix   -1.217
# 192  23800     Bryce Molder   -1.443
# 193  02036     Jim Rutledge   -1.466
# 194  01473    Todd Hamilton   -1.554
# 195  26360  Bubba Dickerson   -1.630
#
# [196 rows x 3 columns]
#        PID           PLAYER SG_ApproachGreen
# 0    08793      Tiger Woods            1.653
# 1    06522        Ernie Els             .994
# 2    10885   Robert Allenby             .845
# 3    06527   Steve Stricker             .811
# 4    21209    Sergio Garcia             .784
# ..     ...              ...              ...
# 191  21806         Paul Gow            -.824
# 192  23800     Bryce Molder            -.832
# 193  01473    Todd Hamilton            -.883
# 194  02036     Jim Rutledge            -.944
# 195  26360  Bubba Dickerson            -.945
#
# [196 rows x 3 columns]
#        PID            PLAYER SG_Putting
# 0    12660   Jesper Parnevik       .979
# 1    08793       Tiger Woods       .712
# 2    23135         Tim Clark       .695
# 3    21731  Freddie Jacobson       .660
# 4    24024      Zach Johnson       .659
# ..     ...               ...        ...
# 191  26679     Kevin Stadler      -.750
# 192  20105         Jeff Gove      -.774
# 193  20691         Greg Owen      -.848
# 194  06621        Joe Durant      -.901
# 195  22295     Darron Stiles     -1.017
#
# [196 rows x 3 columns]
#        PID               PLAYER SG_OffTee
# 0    26289          Boo Weekley      .876
# 1    27141          J.B. Holmes      .828
# 2    06621           Joe Durant      .698
# 3    20574        Mathew Goggin      .691
# 4    23349       Charles Warren      .680
# ..     ...                  ...       ...
# 191  20623          Gavin Coles     -.666
# 192  10213          Dicky Pride     -.699
# 193  06373  José María Olazábal     -.879
# 194  23800         Bryce Molder     -.956
# 195  01928          Corey Pavin     -.968
#
# [196 rows x 3 columns]
#        PID             PLAYER SG_AroundGreen
# 0    24138        Ian Poulter           .653
# 1    20127        Chris Riley           .644
# 2    24357          K.J. Choi           .632
# 3    22371     Aaron Baddeley           .535
# 4    01810     Phil Mickelson           .499
# ..     ...                ...            ...
# 191  24980  Scott Gutschewski          -.456
# 192  21646     David Branshaw          -.500
# 193  11123        Chris Couch          -.517
# 194  24358    Robert Garrigus          -.609
# 195  27702       Matt Hendrix          -.780
#
# [196 rows x 3 columns]
#        PID           PLAYER SG_TeeToGreen
# 0    08793      Tiger Woods         2.380
# 1    06522        Ernie Els         1.609
# 2    01810   Phil Mickelson         1.441
# 3    06567      Vijay Singh         1.402
# 4    20472       Alex Cejka         1.207
# ..     ...              ...           ...
# 191  26360  Bubba Dickerson         -.970
# 192  02036     Jim Rutledge        -1.042
# 193  12714    Chris Tidland        -1.253
# 194  01473    Todd Hamilton        -1.585
# 195  23800     Bryce Molder        -1.629
#
# [196 rows x 3 columns]
#        PID               PLAYER FedExCupPoints
# 0    08793          Tiger Woods         30,574
# 1    06567          Vijay Singh         19,129
# 2    10809            Jim Furyk         16,691
# 3    01810       Phil Mickelson         16,037
# 4    24357            K.J. Choi         15,485
# ..     ...                  ...            ...
# 248  08339          Spike McRoy             50
# 249  07003  David Berganio, Jr.             44
# 250  02294          Willie Wood             44
# 251  06214            Guy Boros             30
# 252  06044           Scott Gump             28
#
# [253 rows x 3 columns]
#        PID          PLAYER Top10Finishes
# 0    08793     Tiger Woods            12
# 1    23621  Rory Sabbatini            10
# 2    02239  Scott Verplank            10
# 3    06527  Steve Stricker             9
# 4    10885  Robert Allenby             8
# ..     ...             ...           ...
# 175  25679     B.J. Staten             1
# 176  12714   Chris Tidland             1
# 177  12755    Vance Veazey             1
# 178  10425  Jay Williamson             1
# 179  20436  Garrett Willis             1
#
# [180 rows x 3 columns]
#        PID            PLAYER WorldRank
# 0    08793       Tiger Woods     20.40
# 1    01810    Phil Mickelson      9.04
# 2    10809         Jim Furyk      6.86
# 3    06527    Steve Stricker      6.65
# 4    06522         Ernie Els      6.60
# ..     ...               ...       ...
# 992  27436     Graham DeLaet       .05
# 993  24594  Bjorn Pettersson       .05
# 994  29952    Carlos Cardeza       .05
# 995  29518    Brendan Steele       .05
# 996  24526        Lu Wei-Ian       .05
#
# [997 rows x 3 columns]
#        PID          PLAYER        Money
# 0    08793     Tiger Woods  $10,867,052
# 1    01810  Phil Mickelson   $5,819,988
# 2    06567     Vijay Singh   $4,728,376
# 3    06527  Steve Stricker   $4,663,077
# 4    24357       K.J. Choi   $4,587,859
# ..     ...             ...          ...
# 251  06573     Brandt Jobe      $11,016
# 252  23043    Paul Sheehan      $10,143
# 253  02294     Willie Wood       $8,700
# 254  06044      Scott Gump       $7,805
# 255  06214       Guy Boros       $7,269
#
# [256 rows x 3 columns]
#        PID            PLAYER BirdieAvg
# 0    23320       Ryan Palmer      4.16
# 1    24358   Robert Garrigus      3.89
# 2    02223          Bob Tway      3.87
# 3    01553       John Huston      3.86
# 4    27770   Camilo Villegas      3.83
# ..     ...               ...       ...
# 192  26420   Richard Johnson      2.83
# 193  12680  Shigeki Maruyama      2.82
# 194  09011       David Duval      2.78
# 195  01139       Olin Browne      2.70
# 196  20382    Stephen Leaney      2.68
#
# [197 rows x 3 columns]
#        PID           PLAYER DrivingDistance
# 0    25804     Bubba Watson           315.1
# 1    24358  Robert Garrigus           311.0
# 2    27141      J.B. Holmes           310.3
# 3    30925   Dustin Johnson           309.7
# 4    21633      Steve Allan           303.2
# ..     ...              ...             ...
# 192  25190     Jeff Quinney           272.5
# 193  01139      Olin Browne           272.1
# 194  20623      Gavin Coles           271.5
# 195  19846        Brian Gay           270.5
# 196  01928      Corey Pavin           261.4
#
# [197 rows x 3 columns]
#        PID             PLAYER TotalDriving
# 0    22892         Jason Gore           56
# 1    23349     Charles Warren           85
# 2    28780  Nicholas Thompson           88
# 3    27933       John Merrick          100
# 4    02002       John Riegger          105
# ..     ...                ...          ...
# 192  06527     Steve Stricker          313
# 193  21350        Ryuji Imada          317
# 194  23797      Brett Rumford          322
# 195  25720       Chad Collins          330
# 196  12680   Shigeki Maruyama          360
#
# [197 rows x 3 columns]
#        PID           PLAYER   GIR%
# 0    06621       Joe Durant  71.10
# 1    10885   Robert Allenby  70.40
# 2    21805  Harrison Frazar  70.34
# 3    01553      John Huston  70.30
# 4    20498      Briny Baird  70.00
# ..     ...              ...    ...
# 192  01707     Steve Lowery  59.38
# 193  25562    Andres Romero  58.79
# 194  23157  Richard Johnson  58.44
# 195  01928      Corey Pavin  57.95
# 196  09011      David Duval  57.84
#
# [197 rows x 3 columns]
#        PID          PLAYER Scrambling
# 0    19846       Brian Gay      64.82
# 1    20127     Chris Riley      64.75
# 2    01928     Corey Pavin      64.43
# 3    20160      Charlie Wi      63.14
# 4    20498     Briny Baird      62.43
# ..     ...             ...        ...
# 192  25594  Travis Perkins      50.15
# 193  19803     Ryan Armour      49.61
# 194  09011     David Duval      49.10
# 195  23349  Charles Warren      48.41
# 196  30750    Tommy Gainey      46.10
#
# [197 rows x 3 columns]
#        PID          PLAYER SG_Total
# 0    01810  Phil Mickelson    1.818
# 1    21209   Sergio Garcia    1.548
# 2    29718     Anthony Kim    1.479
# 3    06567     Vijay Singh    1.467
# 4    10885  Robert Allenby    1.407
# ..     ...             ...      ...
# 192  30750    Tommy Gainey   -1.401
# 193  22582   Kyle Thompson   -1.527
# 194  27613  David Lutterus   -1.701
# 195  25594  Travis Perkins   -1.756
# 196  09011     David Duval   -1.876
#
# [197 rows x 3 columns]
#        PID           PLAYER SG_ApproachGreen
# 0    10885   Robert Allenby            1.217
# 1    21209    Sergio Garcia             .891
# 2    01810   Phil Mickelson             .842
# 3    12510    Chad Campbell             .830
# 4    06522        Ernie Els             .790
# ..     ...              ...              ...
# 192  22582    Kyle Thompson            -.749
# 193  21633      Steve Allan            -.758
# 194  20850    Daniel Chopra            -.760
# 195  10875      Todd Demsey            -.906
# 196  23157  Richard Johnson            -.962
#
# [197 rows x 3 columns]
#        PID           PLAYER SG_Putting
# 0    01928      Corey Pavin       .973
# 1    02223         Bob Tway       .822
# 2    26668     Marc Turnesa       .789
# 3    20850    Daniel Chopra       .786
# 4    22371   Aaron Baddeley       .762
# ..     ...              ...        ...
# 192  01388     Robert Gamez      -.904
# 193  21805  Harrison Frazar      -.912
# 194  30750     Tommy Gainey      -.919
# 195  23349   Charles Warren      -.947
# 196  06621       Joe Durant      -.978
#
# [197 rows x 3 columns]
#        PID             PLAYER SG_OffTee
# 0    27141        J.B. Holmes      .866
# 1    06567        Vijay Singh      .819
# 2    26289        Boo Weekley      .715
# 3    23349     Charles Warren      .683
# 4    28780  Nicholas Thompson      .611
# ..     ...                ...       ...
# 192  23048         Eric Axley     -.785
# 193  25190       Jeff Quinney     -.965
# 194  01928        Corey Pavin    -1.058
# 195  25720       Chad Collins    -1.078
# 196  09011        David Duval    -1.297
#
# [197 rows x 3 columns]
#        PID            PLAYER SG_AroundGreen
# 0    20127       Chris Riley           .650
# 1    10423         Mike Weir           .541
# 2    23797     Brett Rumford           .526
# 3    12680  Shigeki Maruyama           .470
# 4    25396          Kevin Na           .470
# ..     ...               ...            ...
# 192  06573       Brandt Jobe          -.444
# 193  30750      Tommy Gainey          -.461
# 194  27561     Nick Flanagan          -.498
# 195  23349    Charles Warren          -.504
# 196  19803       Ryan Armour          -.639
#
# [197 rows x 3 columns]
#        PID           PLAYER SG_TeeToGreen
# 0    06567      Vijay Singh         1.875
# 1    21209    Sergio Garcia         1.625
# 2    01810   Phil Mickelson         1.604
# 3    10885   Robert Allenby         1.546
# 4    24502       Adam Scott         1.299
# ..     ...              ...           ...
# 192  23157  Richard Johnson        -1.124
# 193  25720     Chad Collins        -1.131
# 194  25594   Travis Perkins        -1.181
# 195  22582    Kyle Thompson        -1.197
# 196  09011      David Duval        -1.716
#
# [197 rows x 3 columns]
#        PID              PLAYER FedExCupPoints
# 0    08793         Tiger Woods         22,695
# 1    01945         Kenny Perry         20,878
# 2    01810      Phil Mickelson         18,241
# 3    20766  Padraig Harrington         15,555
# 4    29718         Anthony Kim         15,178
# ..     ...                 ...            ...
# 257  02246       Duffy Waldorf             26
# 258  08339         Spike McRoy             26
# 259  01331           Rick Fehr             25
# 260  06809           Bob Burns             24
# 261  01385  Jim Gallagher, Jr.             24
#
# [262 rows x 3 columns]
#        PID            PLAYER Top10Finishes
# 0    10885    Robert Allenby             9
# 1    10809         Jim Furyk             9
# 2    29718       Anthony Kim             8
# 3    10860    Justin Leonard             8
# 4    01810    Phil Mickelson             8
# ..     ...               ...           ...
# 183  27095       Nick Watney             1
# 184  10425    Jay Williamson             1
# 185  26497  Casey Wittenberg             1
# 186  22000        Chris Wood             1
# 187  24663         Y.E. Yang             1
#
# [188 rows x 3 columns]
#        PID              PLAYER WorldRank
# 0    08793         Tiger Woods     11.66
# 1    21209       Sergio Garcia      7.99
# 2    01810      Phil Mickelson      6.87
# 3    20766  Padraig Harrington      6.83
# 4    06567         Vijay Singh      6.63
# ..     ...                 ...       ...
# 992  29134         Jin-won Lee       .05
# 993  29764        Justin Itzen       .05
# 994  28526       Damian Ulrich       .05
# 995  11123         Chris Couch       .05
# 996  30632        Mark Lawless       .04
#
# [997 rows x 3 columns]
#        PID          PLAYER       Money
# 0    06567     Vijay Singh  $6,601,094
# 1    08793     Tiger Woods  $5,775,000
# 2    01810  Phil Mickelson  $5,188,875
# 3    21209   Sergio Garcia  $4,858,224
# 4    01945     Kenny Perry  $4,663,794
# ..     ...             ...         ...
# 257  02246   Duffy Waldorf      $7,350
# 258  06809       Bob Burns      $6,650
# 259  01927  Dennis Paulson      $6,420
# 260  02067      Ted Schulz      $6,420
# 261  01331       Rick Fehr      $5,940
#
# [262 rows x 3 columns]
#        PID         PLAYER BirdieAvg
# 0    08793    Tiger Woods      4.15
# 1    29718    Anthony Kim      4.11
# 2    24781   Hunter Mahan      4.11
# 3    24925  Jonathan Byrd      4.09
# 4    06004   Stephen Ames      4.07
# ..     ...            ...       ...
# 179  30927   Brendon Todd      2.89
# 180  26668   Marc Turnesa      2.87
# 181  06012     Greg Kraft      2.86
# 182  01677     Tom Lehman      2.78
# 183  01329     Brad Faxon      2.76
#
# [184 rows x 3 columns]
#        PID           PLAYER DrivingDistance
# 0    24358  Robert Garrigus           312.0
# 1    25804     Bubba Watson           311.4
# 2    30925   Dustin Johnson           308.3
# 3    23497      Tag Ridings           307.4
# 4    31323    Gary Woodland           307.3
# ..     ...              ...             ...
# 179  01329       Brad Faxon           270.8
# 180  12602      Dean Wilson           270.3
# 181  01132      Mark Brooks           269.2
# 182  19846        Brian Gay           268.5
# 183  01928      Corey Pavin           259.0
#
# [184 rows x 3 columns]
#        PID            PLAYER TotalDriving
# 0    24925     Jonathan Byrd           92
# 1    25900      Lucas Glover           95
# 2    01945       Kenny Perry           97
# 3    22913      John Rollins           97
# 4    10885    Robert Allenby           98
# ..     ...               ...          ...
# 179  21350       Ryuji Imada          290
# 180  30927      Brendon Todd          291
# 181  23048        Eric Axley          315
# 182  01329        Brad Faxon          324
# 183  24449  Parker McLachlin          330
#
# [184 rows x 3 columns]
#        PID            PLAYER   GIR%
# 0    20645       John Senden  70.89
# 1    24925     Jonathan Byrd  70.59
# 2    06621        Joe Durant  70.58
# 3    24358   Robert Garrigus  70.53
# 4    10425    Jay Williamson  70.49
# ..     ...               ...    ...
# 179  31416    Derek Fathauer  60.33
# 180  22371    Aaron Baddeley  59.57
# 181  24449  Parker McLachlin  58.37
# 182  23048        Eric Axley  57.30
# 183  01329        Brad Faxon  52.35
#
# [184 rows x 3 columns]
#        PID          PLAYER Scrambling
# 0    08793     Tiger Woods      68.18
# 1    06527  Steve Stricker      66.46
# 2    23108     Matt Kuchar      65.91
# 3    24138     Ian Poulter      65.14
# 4    01948    Tim Petrovic      64.97
# ..     ...             ...        ...
# 179  30927    Brendon Todd      51.13
# 180  25562   Andres Romero      51.11
# 181  23048      Eric Axley      50.49
# 182  09011     David Duval      48.98
# 183  31323   Gary Woodland      45.08
#
# [184 rows x 3 columns]
#        PID          PLAYER SG_Total
# 0    08793     Tiger Woods    3.189
# 1    06527  Steve Stricker    1.828
# 2    10809       Jim Furyk    1.690
# 3    24024    Zach Johnson    1.545
# 4    23135       Tim Clark    1.261
# ..     ...             ...      ...
# 179  06539      Rick Price   -1.518
# 180  27683      Leif Olson   -1.616
# 181  09011     David Duval   -1.728
# 182  01329      Brad Faxon   -1.925
# 183  23048      Eric Axley   -2.157
#
# [184 rows x 3 columns]
#        PID            PLAYER SG_ApproachGreen
# 0    08793       Tiger Woods            1.398
# 1    06527    Steve Stricker            1.018
# 2    10885    Robert Allenby            1.015
# 3    24024      Zach Johnson             .844
# 4    01677        Tom Lehman             .834
# ..     ...               ...              ...
# 179  22621        Ben Curtis            -.642
# 180  30927      Brendon Todd            -.710
# 181  23048        Eric Axley            -.804
# 182  24449  Parker McLachlin            -.976
# 183  01329        Brad Faxon           -1.428
#
# [184 rows x 3 columns]
#        PID           PLAYER SG_Putting
# 0    23983      Luke Donald       .934
# 1    08793      Tiger Woods       .877
# 2    01329       Brad Faxon       .780
# 3    22621       Ben Curtis       .766
# 4    27649  Brandt Snedeker       .761
# ..     ...              ...        ...
# 179  24502       Adam Scott      -.881
# 180  10425   Jay Williamson      -.895
# 181  01766    Billy Mayfair      -.910
# 182  24912   Will MacKenzie      -.991
# 183  24846     Ricky Barnes     -1.216
#
# [184 rows x 3 columns]
#        PID            PLAYER SG_OffTee
# 0    27095       Nick Watney      .732
# 1    26289       Boo Weekley      .721
# 2    28158      Steve Marino      .668
# 3    25900      Lucas Glover      .638
# 4    24781      Hunter Mahan      .628
# ..     ...               ...       ...
# 179  01928       Corey Pavin     -.974
# 180  01329        Brad Faxon    -1.030
# 181  24449  Parker McLachlin    -1.036
# 182  09011       David Duval    -1.330
# 183  23048        Eric Axley    -1.441
#
# [184 rows x 3 columns]
#        PID              PLAYER SG_AroundGreen
# 0    20127         Chris Riley           .728
# 1    24138         Ian Poulter           .650
# 2    08793         Tiger Woods           .579
# 3    20766  Padraig Harrington           .577
# 4    10809           Jim Furyk           .439
# ..     ...                 ...            ...
# 179  06539          Rick Price          -.390
# 180  06621          Joe Durant          -.404
# 181  01707        Steve Lowery          -.473
# 182  06012          Greg Kraft          -.474
# 183  31323       Gary Woodland          -.520
#
# [184 rows x 3 columns]
#        PID            PLAYER SG_TeeToGreen
# 0    08793       Tiger Woods         2.311
# 1    06527    Steve Stricker         1.621
# 2    10885    Robert Allenby         1.619
# 3    06522         Ernie Els         1.315
# 4    24140       Sean O'Hair         1.297
# ..     ...               ...           ...
# 179  30927      Brendon Todd        -1.447
# 180  09011       David Duval        -1.602
# 181  24449  Parker McLachlin        -1.760
# 182  23048        Eric Axley        -2.498
# 183  01329        Brad Faxon        -2.705
#
# [184 rows x 3 columns]
#        PID          PLAYER FedExCupPoints
# 0    08793     Tiger Woods          3,431
# 1    06527  Steve Stricker          2,155
# 2    24024    Zach Johnson          2,019
# 3    01945     Kenny Perry          1,993
# 4    25900    Lucas Glover          1,742
# ..     ...             ...            ...
# 250  01887    Mark O'Meara              1
# 251  01876     Greg Norman              1
# 252  01926      Steve Pate              1
# 253  01374   Robin Freeman              1
# 254  01685      J.L. Lewis              0
#
# [255 rows x 3 columns]
#        PID            PLAYER Top10Finishes
# 0    08793       Tiger Woods            14
# 1    10809         Jim Furyk            11
# 2    06527    Steve Stricker            11
# 3    24024      Zach Johnson             9
# 4    25396          Kevin Na             9
# ..     ...               ...           ...
# 186  26289       Boo Weekley             1
# 187  26498     Matt Weibring             1
# 188  25349     Tim Wilkinson             1
# 189  26497  Casey Wittenberg             1
# 190  22000        Chris Wood             1
#
# [191 rows x 3 columns]
#        PID              PLAYER WorldRank
# 0    08793         Tiger Woods     15.20
# 1    01810      Phil Mickelson      8.54
# 2    06527      Steve Stricker      6.89
# 3    20396        Lee Westwood      6.76
# 4    20766  Padraig Harrington      5.75
# ..     ...                 ...       ...
# 993  27034          Simon Dunn       .05
# 994  01938       David Peoples       .05
# 995  32353    Somchai Pongpaew       .05
# 996  20474       Phillip Price       .05
# 997  32511    Thomas Sherreard       .05
#
# [998 rows x 3 columns]
#        PID          PLAYER        Money
# 0    08793     Tiger Woods  $10,508,163
# 1    06527  Steve Stricker   $6,332,636
# 2    01810  Phil Mickelson   $5,332,755
# 3    24024    Zach Johnson   $4,714,813
# 4    01945     Kenny Perry   $4,445,562
# ..     ...             ...          ...
# 253  10649    Tom Scherrer       $9,364
# 254  01374   Robin Freeman       $6,930
# 255  02245     Grant Waite       $6,756
# 256  01926      Steve Pate       $6,030
# 257  01685      J.L. Lewis       $5,820
#
# [258 rows x 3 columns]
#        PID           PLAYER BirdieAvg
# 0    08725       Tom Gillis      4.06
# 1    08375  Paul Stankowski      4.03
# 2    11123      Chris Couch      4.02
# 3    27095      Nick Watney      4.01
# 4    28307       Matt Every      4.00
# ..     ...              ...       ...
# 187  22378  Trevor Immelman      2.95
# 188  20105        Jeff Gove      2.88
# 189  24227     Justin Bolli      2.82
# 190  07363     Craig Bowden      2.80
# 191  06012       Greg Kraft      2.79
#
# [192 rows x 3 columns]
#        PID           PLAYER DrivingDistance
# 0    24358  Robert Garrigus           315.5
# 1    25804     Bubba Watson           309.8
# 2    30925   Dustin Johnson           308.5
# 3    23322  Brett Wetterich           307.3
# 4    27141      J.B. Holmes           307.2
# ..     ...              ...             ...
# 187  23135        Tim Clark           272.2
# 188  08385      Omar Uresti           272.0
# 189  01329       Brad Faxon           271.4
# 190  07363     Craig Bowden           270.0
# 191  19846        Brian Gay           266.4
#
# [192 rows x 3 columns]
#        PID          PLAYER TotalDriving
# 0    23349  Charles Warren           70
# 1    27436   Graham DeLaet           84
# 2    24781    Hunter Mahan           95
# 3    01706  Davis Love III          102
# 4    26289     Boo Weekley          102
# ..     ...             ...          ...
# 187  06012      Greg Kraft          306
# 188  25720    Chad Collins          324
# 189  20593   Greg Chalmers          333
# 190  01329      Brad Faxon          343
# 191  10423       Mike Weir          369
#
# [192 rows x 3 columns]
#        PID            PLAYER   GIR%
# 0    20645       John Senden  72.49
# 1    06595  Kevin Sutherland  71.96
# 2    06621        Joe Durant  71.95
# 3    23349    Charles Warren  71.74
# 4    27120     Troy Matteson  71.43
# ..     ...               ...    ...
# 187  06012        Greg Kraft  60.63
# 188  20070  Matt Bettencourt  60.17
# 189  01329        Brad Faxon  59.05
# 190  32617      Jerod Turner  58.94
# 191  10423         Mike Weir  57.89
#
# [192 rows x 3 columns]
#        PID             PLAYER Scrambling
# 0    12602        Dean Wilson      67.16
# 1    19846          Brian Gay      66.51
# 2    20160         Charlie Wi      65.56
# 3    23983        Luke Donald      65.41
# 4    23108        Matt Kuchar      64.69
# ..     ...                ...        ...
# 187  01707       Steve Lowery      50.38
# 188  20105          Jeff Gove      50.36
# 189  22946   Henrik Bjornstad      49.59
# 190  28780  Nicholas Thompson      49.38
# 191  01329         Brad Faxon      47.49
#
# [192 rows x 3 columns]
#        PID          PLAYER SG_Total
# 0    06527  Steve Stricker    1.818
# 1    20157   Retief Goosen    1.598
# 2    10809       Jim Furyk    1.564
# 3    23983     Luke Donald    1.493
# 4    23108     Matt Kuchar    1.461
# ..     ...             ...      ...
# 187  32617    Jerod Turner   -1.885
# 188  24227    Justin Bolli   -1.918
# 189  06012      Greg Kraft   -2.041
# 190  01329      Brad Faxon   -2.093
# 191  06514   Kevin Johnson   -2.147
#
# [192 rows x 3 columns]
#        PID            PLAYER SG_ApproachGreen
# 0    24502        Adam Scott            1.164
# 1    06567       Vijay Singh             .979
# 2    06527    Steve Stricker             .773
# 3    27770   Camilo Villegas             .755
# 4    01810    Phil Mickelson             .738
# ..     ...               ...              ...
# 187  22371    Aaron Baddeley            -.797
# 188  20070  Matt Bettencourt            -.831
# 189  06514     Kevin Johnson            -.895
# 190  20850     Daniel Chopra           -1.070
# 191  32617      Jerod Turner           -1.179
#
# [192 rows x 3 columns]
#        PID             PLAYER SG_Putting
# 0    23983        Luke Donald       .874
# 1    25364         Paul Casey       .824
# 2    25345    Carl Pettersson       .817
# 3    12602        Dean Wilson       .780
# 4    20593      Greg Chalmers       .778
# ..     ...                ...        ...
# 187  23307   Roger Tambellini      -.775
# 188  01161  Mark Calcavecchia      -.870
# 189  28780  Nicholas Thompson      -.886
# 190  20105          Jeff Gove      -.953
# 191  01766      Billy Mayfair     -1.010
#
# [192 rows x 3 columns]
#        PID           PLAYER SG_OffTee
# 0    25804     Bubba Watson      .798
# 1    30925   Dustin Johnson      .760
# 2    24358  Robert Garrigus      .730
# 3    27141      J.B. Holmes      .729
# 4    23623      Bo Van Pelt      .724
# ..     ...              ...       ...
# 187  06012       Greg Kraft     -.876
# 188  23613     Rich Barcelo    -1.027
# 189  12755     Vance Veazey    -1.117
# 190  10423        Mike Weir    -1.246
# 191  01329       Brad Faxon    -1.343
#
# [192 rows x 3 columns]
#        PID              PLAYER SG_AroundGreen
# 0    10423           Mike Weir           .559
# 1    23983         Luke Donald           .464
# 2    22405         Justin Rose           .447
# 3    28089           Jason Day           .444
# 4    06527      Steve Stricker           .419
# ..     ...                 ...            ...
# 187  29285  Brent Delahoussaye          -.465
# 188  22946    Henrik Bjornstad          -.490
# 189  01329          Brad Faxon          -.553
# 190  01707        Steve Lowery          -.607
# 191  24358     Robert Garrigus          -.845
#
# [192 rows x 3 columns]
#        PID          PLAYER SG_TeeToGreen
# 0    24502      Adam Scott         1.609
# 1    06567     Vijay Singh         1.494
# 2    06527  Steve Stricker         1.383
# 3    10809       Jim Furyk         1.159
# 4    01810  Phil Mickelson         1.151
# ..     ...             ...           ...
# 187  20850   Daniel Chopra        -1.461
# 188  06514   Kevin Johnson        -1.795
# 189  06012      Greg Kraft        -1.856
# 190  32617    Jerod Turner        -1.883
# 191  01329      Brad Faxon        -2.519
#
# [192 rows x 3 columns]
#        PID          PLAYER FedExCupPoints
# 0    06522       Ernie Els          1,846
# 1    06527  Steve Stricker          1,697
# 2    10809       Jim Furyk          1,691
# 3    01810  Phil Mickelson          1,629
# 4    22405     Justin Rose          1,593
# ..     ...             ...            ...
# 243  02294     Willie Wood              5
# 244  01374   Robin Freeman              2
# 245  23778   Brad Adamonis              2
# 246  01042    Paul Azinger              1
# 247  08339     Spike McRoy              0
#
# [248 rows x 3 columns]
#        PID            PLAYER Top10Finishes
# 0    23108       Matt Kuchar            11
# 1    20157     Retief Goosen            10
# 2    06527    Steve Stricker             9
# 3    23623       Bo Van Pelt             8
# 4    27095       Nick Watney             8
# ..     ...               ...           ...
# 190  25892  Steve Wheatcroft             1
# 191  10425    Jay Williamson             1
# 192  20436    Garrett Willis             1
# 193  12602       Dean Wilson             1
# 194  27506     Oliver Wilson             1
#
# [195 rows x 3 columns]
#        PID          PLAYER WorldRank
# 0    20396    Lee Westwood      9.31
# 1    08793     Tiger Woods      8.26
# 2    27408   Martin Kaymer      7.49
# 3    01810  Phil Mickelson      7.01
# 4    10809       Jim Furyk      6.44
# ..     ...             ...       ...
# 992  27939  Matt McQuillan       .05
# 993  21002     Óscar Serna       .05
# 994  26975  Grant Veenstra       .05
# 995  28823   Mark Williams       .05
# 996  27630      Jay Bayron       .05
#
# [997 rows x 3 columns]
#        PID              PLAYER       Money
# 0    23108         Matt Kuchar  $4,910,477
# 1    10809           Jim Furyk  $4,809,622
# 2    06522           Ernie Els  $4,558,861
# 3    30925      Dustin Johnson  $4,473,122
# 4    06527      Steve Stricker  $4,190,235
# ..     ...                 ...         ...
# 243  01042        Paul Azinger      $9,486
# 244  12660     Jesper Parnevik      $9,165
# 245  08339         Spike McRoy      $6,840
# 246  01385  Jim Gallagher, Jr.      $6,552
# 247  02294         Willie Wood      $6,540
#
# [248 rows x 3 columns]
#        PID             PLAYER BirdieAvg
# 0    06527     Steve Stricker      4.28
# 1    23983        Luke Donald      4.24
# 2    29221       Webb Simpson      4.23
# 3    30925     Dustin Johnson      4.20
# 4    27095        Nick Watney      4.10
# ..     ...                ...       ...
# 181  32640       Troy Merritt      2.94
# 182  06515      Shaun Micheel      2.92
# 183  26420    Richard Johnson      2.84
# 184  25834  Daniel Summerhays      2.76
# 185  23614          Rich Beem      2.75
#
# [186 rows x 3 columns]
#        PID           PLAYER DrivingDistance
# 0    27141      J.B. Holmes           318.4
# 1    25804     Bubba Watson           314.9
# 2    30925   Dustin Johnson           314.2
# 3    24358  Robert Garrigus           313.4
# 4    31323    Gary Woodland           310.5
# ..     ...              ...             ...
# 181  22348      Nick O'Hern           276.3
# 182  08075      Jerry Kelly           275.6
# 183  01797    Rocco Mediate           275.5
# 184  06643      Paul Goydos           274.8
# 185  19846        Brian Gay           269.8
#
# [186 rows x 3 columns]
#        PID            PLAYER TotalDriving
# 0    27933      John Merrick           66
# 1    22913      John Rollins           74
# 2    06573       Brandt Jobe           76
# 3    26289       Boo Weekley           79
# 4    24502        Adam Scott           86
# ..     ...               ...          ...
# 181  20070  Matt Bettencourt          277
# 182  08375   Paul Stankowski          277
# 183  06515     Shaun Micheel          294
# 184  21407       Arjun Atwal          305
# 185  25396          Kevin Na          312
#
# [186 rows x 3 columns]
#        PID          PLAYER   GIR%
# 0    26289     Boo Weekley  71.68
# 1    22293    Heath Slocum  71.40
# 2    06621      Joe Durant  71.26
# 3    12510   Chad Campbell  71.13
# 4    20645     John Senden  70.86
# ..     ...             ...    ...
# 181  24290    D.J. Brigman  60.92
# 182  10585  Scott McCarron  60.75
# 183  29478    Kevin Kisner  60.59
# 184  07457    Steve Flesch  59.85
# 185  35087         Bio Kim  59.49
#
# [186 rows x 3 columns]
#        PID          PLAYER Scrambling
# 0    20593   Greg Chalmers      65.17
# 1    06527  Steve Stricker      64.93
# 2    28089       Jason Day      64.64
# 3    24024    Zach Johnson      63.98
# 4    07867    Woody Austin      63.92
# ..     ...             ...        ...
# 181  06522       Ernie Els      51.07
# 182  27797    Derek Lamely      50.83
# 183  25804    Bubba Watson      50.82
# 184  25444    Justin Hicks      50.47
# 185  30946      Alex Prugh      47.91
#
# [186 rows x 3 columns]
#        PID             PLAYER SG_Total
# 0    23983        Luke Donald    2.278
# 1    29221       Webb Simpson    1.764
# 2    06527     Steve Stricker    1.730
# 3    27095        Nick Watney    1.712
# 4    23108        Matt Kuchar    1.540
# ..     ...                ...      ...
# 181  32876      Martin Piller   -1.351
# 182  27797       Derek Lamely   -1.383
# 183  25444       Justin Hicks   -1.416
# 184  01797      Rocco Mediate   -1.522
# 185  25834  Daniel Summerhays   -1.581
#
# [186 rows x 3 columns]
#        PID          PLAYER SG_ApproachGreen
# 0    23983     Luke Donald            1.094
# 1    12510   Chad Campbell             .987
# 2    01810  Phil Mickelson             .900
# 3    29221    Webb Simpson             .755
# 4    23108     Matt Kuchar             .698
# ..     ...             ...              ...
# 181  30711      Colt Knost            -.672
# 182  01797   Rocco Mediate            -.682
# 183  29478    Kevin Kisner            -.707
# 184  35087         Bio Kim            -.838
# 185  10585  Scott McCarron           -1.240
#
# [186 rows x 3 columns]
#        PID          PLAYER SG_Putting
# 0    23983     Luke Donald       .870
# 1    20160      Charlie Wi       .808
# 2    06527  Steve Stricker       .780
# 3    23800    Bryce Molder       .770
# 4    25396        Kevin Na       .650
# ..     ...             ...        ...
# 181  06522       Ernie Els      -.705
# 182  23788     D.J. Trahan      -.815
# 183  06621      Joe Durant      -.861
# 184  25444    Justin Hicks      -.955
# 185  26289     Boo Weekley     -1.100
#
# [186 rows x 3 columns]
#        PID             PLAYER SG_OffTee
# 0    30925     Dustin Johnson      .912
# 1    25804       Bubba Watson      .898
# 2    24502         Adam Scott      .793
# 3    31323      Gary Woodland      .742
# 4    27141        J.B. Holmes      .726
# ..     ...                ...       ...
# 181  21407        Arjun Atwal     -.705
# 182  25834  Daniel Summerhays     -.719
# 183  25396           Kevin Na     -.757
# 184  12602        Dean Wilson     -.863
# 185  33911         Nate Smith     -.882
#
# [186 rows x 3 columns]
#        PID           PLAYER SG_AroundGreen
# 0    25396         Kevin Na           .593
# 1    20127      Chris Riley           .590
# 2    35087          Bio Kim           .515
# 3    22371   Aaron Baddeley           .438
# 4    19846        Brian Gay           .425
# ..     ...              ...            ...
# 181  30946       Alex Prugh          -.470
# 182  25444     Justin Hicks          -.472
# 183  30692  Scott Stallings          -.475
# 184  32876    Martin Piller          -.623
# 185  20848    Ángel Cabrera          -.679
#
# [186 rows x 3 columns]
#        PID             PLAYER SG_TeeToGreen
# 0    29221       Webb Simpson         1.492
# 1    23983        Luke Donald         1.408
# 2    01810     Phil Mickelson         1.373
# 3    30110       Kyle Stanley         1.171
# 4    27095        Nick Watney         1.165
# ..     ...                ...           ...
# 181  26420    Richard Johnson        -1.161
# 182  25834  Daniel Summerhays        -1.288
# 183  33911         Nate Smith        -1.293
# 184  34072     Will Strickler        -1.294
# 185  32876      Martin Piller        -1.559
#
# [186 rows x 3 columns]
#        PID          PLAYER FedExCupPoints
# 0    27095     Nick Watney          1,906
# 1    06527  Steve Stricker          1,865
# 2    29221    Webb Simpson          1,861
# 3    23983     Luke Donald          1,856
# 4    33141  Keegan Bradley          1,621
# ..     ...             ...            ...
# 259  01619    Skip Kendall              1
# 260  01887    Mark O'Meara              1
# 261  27436   Graham DeLaet              1
# 262  01685      J.L. Lewis              0
# 263  07223   Brian Bateman              0
#
# [264 rows x 3 columns]
#        PID          PLAYER Top10Finishes
# 0    23983     Luke Donald            14
# 1    29221    Webb Simpson            12
# 2    28089       Jason Day            10
# 3    27095     Nick Watney            10
# 4    23108     Matt Kuchar             9
# ..     ...             ...           ...
# 172  23788     D.J. Trahan             1
# 173  26668    Marc Turnesa             1
# 174  26951  Johnson Wagner             1
# 175  20160      Charlie Wi             1
# 176  20436  Garrett Willis             1
#
# [177 rows x 3 columns]
#        PID          PLAYER WorldRank
# 0    23983     Luke Donald     10.03
# 1    20396    Lee Westwood      8.06
# 2    28237    Rory McIlroy      7.77
# 3    27408   Martin Kaymer      6.55
# 4    24502      Adam Scott      5.50
# ..     ...             ...       ...
# 993  29309    Kim Wi-joong       .07
# 994  30057     Jesús Rivas       .07
# 995  24872  Tadahisa Inoue       .07
# 996  29706     Toto Thimba       .07
# 997  28067     Sebi Garcia       .07
#
# [998 rows x 3 columns]
#        PID               PLAYER       Money
# 0    23983          Luke Donald  $6,683,214
# 1    29221         Webb Simpson  $6,347,353
# 2    27095          Nick Watney  $5,290,673
# 3    24357            K.J. Choi  $4,434,691
# 4    30925       Dustin Johnson  $4,309,961
# ..     ...                  ...         ...
# 256  06012           Greg Kraft      $7,350
# 257  01685           J.L. Lewis      $7,056
# 258  07223        Brian Bateman      $6,984
# 259  20029      Notah Begay III      $6,690
# 260  06373  José María Olazábal      $6,330
#
# [261 rows x 3 columns]
#        PID            PLAYER BirdieAvg
# 0    28237      Rory McIlroy      4.20
# 1    29221      Webb Simpson      4.11
# 2    27649   Brandt Snedeker      4.01
# 3    24358   Robert Garrigus      3.97
# 4    08793       Tiger Woods      3.97
# ..     ...               ...       ...
# 186  06004      Stephen Ames      2.98
# 187  23903  Stephen Gangluff      2.96
# 188  30852      Ryo Ishikawa      2.96
# 189  29222  Billy Hurley III      2.85
# 190  27974         Sung Kang      2.84
#
# [191 rows x 3 columns]
#        PID           PLAYER DrivingDistance
# 0    25804     Bubba Watson           315.5
# 1    32334   Charlie Beljan           311.6
# 2    24358  Robert Garrigus           310.3
# 3    30925   Dustin Johnson           310.2
# 4    28237     Rory McIlroy           310.1
# ..     ...              ...             ...
# 186  01941  Tom Pernice Jr.           273.9
# 187  06251    Chris DiMarco           273.0
# 188  30711       Colt Knost           272.5
# 189  20623      Gavin Coles           271.2
# 190  22348      Nick O'Hern           268.9
#
# [191 rows x 3 columns]
#        PID            PLAYER TotalDriving
# 0    26289       Boo Weekley           74
# 1    24781      Hunter Mahan           78
# 2    23623       Bo Van Pelt           84
# 3    11123       Chris Couch           85
# 4    25686      Jason Dufner           85
# ..     ...               ...          ...
# 186  30927      Brendon Todd          293
# 187  20070  Matt Bettencourt          299
# 188  27466     Spencer Levin          306
# 189  01116   Michael Bradley          336
# 190  21350       Ryuji Imada          340
#
# [191 rows x 3 columns]
#        PID            PLAYER   GIR%
# 0    22405       Justin Rose  70.34
# 1    25804      Bubba Watson  69.95
# 2    20396      Lee Westwood  69.75
# 3    27770   Camilo Villegas  69.55
# 4    26289       Boo Weekley  69.53
# ..     ...               ...    ...
# 186  27974         Sung Kang  59.15
# 187  20070  Matt Bettencourt  58.95
# 188  24663         Y.E. Yang  58.51
# 189  22371    Aaron Baddeley  58.10
# 190  29222  Billy Hurley III  57.74
#
# [191 rows x 3 columns]
#        PID           PLAYER Scrambling
# 0    19846        Brian Gay      64.38
# 1    24138      Ian Poulter      64.34
# 2    10809        Jim Furyk      63.83
# 3    08793      Tiger Woods      63.17
# 4    23983      Luke Donald      62.66
# ..     ...              ...        ...
# 186  27064  Jhonattan Vegas      49.78
# 187  20848    Ángel Cabrera      49.09
# 188  22582    Kyle Thompson      48.99
# 189  24940      Edward Loar      48.34
# 190  20396     Lee Westwood      48.30
#
# [191 rows x 3 columns]
#        PID            PLAYER SG_Total
# 0    28237      Rory McIlroy    2.406
# 1    08793       Tiger Woods    2.310
# 2    10809         Jim Furyk    1.752
# 3    23983       Luke Donald    1.641
# 4    22405       Justin Rose    1.640
# ..     ...               ...      ...
# 186  20070  Matt Bettencourt   -1.262
# 187  29222  Billy Hurley III   -1.324
# 188  22582     Kyle Thompson   -1.398
# 189  27974         Sung Kang   -1.761
# 190  23903  Stephen Gangluff   -1.959
#
# [191 rows x 3 columns]
#        PID           PLAYER SG_ApproachGreen
# 0    08793      Tiger Woods            1.224
# 1    28237     Rory McIlroy            1.002
# 2    06527   Steve Stricker             .898
# 3    22405      Justin Rose             .840
# 4    10809        Jim Furyk             .830
# ..     ...              ...              ...
# 186  23542  Tommy Biershenk            -.733
# 187  22548  Patrick Sheehan            -.737
# 188  28259     Sangmoon Bae            -.760
# 189  27974        Sung Kang            -.897
# 190  30927     Brendon Todd           -1.141
#
# [191 rows x 3 columns]
#        PID           PLAYER SG_Putting
# 0    27649  Brandt Snedeker       .860
# 1    23983      Luke Donald       .818
# 2    27895      Jonas Blixt       .804
# 3    19846        Brian Gay       .704
# 4    23800     Bryce Molder       .666
# ..     ...              ...        ...
# 186  28087      Kris Blanks      -.608
# 187  06036     Scott Dunlap      -.688
# 188  30110     Kyle Stanley      -.797
# 189  26289      Boo Weekley     -1.055
# 190  22582    Kyle Thompson     -1.209
#
# [191 rows x 3 columns]
#        PID            PLAYER SG_OffTee
# 0    25804      Bubba Watson     1.485
# 1    28237      Rory McIlroy     1.072
# 2    32334    Charlie Beljan      .797
# 3    24358   Robert Garrigus      .797
# 4    30110      Kyle Stanley      .786
# ..     ...               ...       ...
# 186  21350       Ryuji Imada     -.919
# 187  01941   Tom Pernice Jr.     -.921
# 188  23903  Stephen Gangluff     -.932
# 189  29222  Billy Hurley III     -.967
# 190  01116   Michael Bradley    -1.146
#
# [191 rows x 3 columns]
#        PID           PLAYER SG_AroundGreen
# 0    22405      Justin Rose           .567
# 1    20593    Greg Chalmers           .459
# 2    23983      Luke Donald           .430
# 3    20160       Charlie Wi           .430
# 4    22348      Nick O'Hern           .424
# ..     ...              ...            ...
# 186  28259     Sangmoon Bae          -.491
# 187  26287  Roland Thatcher          -.498
# 188  24940      Edward Loar          -.594
# 189  01249        John Daly          -.604
# 190  32334   Charlie Beljan          -.635
#
# [191 rows x 3 columns]
#        PID            PLAYER SG_TeeToGreen
# 0    28237      Rory McIlroy         2.347
# 1    08793       Tiger Woods         1.971
# 2    25804      Bubba Watson         1.809
# 3    22405       Justin Rose         1.762
# 4    10809         Jim Furyk         1.329
# ..     ...               ...           ...
# 186  29222  Billy Hurley III        -1.600
# 187  30927      Brendon Todd        -1.617
# 188  27797      Derek Lamely        -1.671
# 189  23903  Stephen Gangluff        -1.716
# 190  27974         Sung Kang        -1.812
#
# [191 rows x 3 columns]
#        PID           PLAYER FedExCupPoints
# 0    08793      Tiger Woods          2,269
# 1    25686     Jason Dufner          2,110
# 2    28237     Rory McIlroy          2,092
# 3    24024     Zach Johnson          2,019
# 4    25804     Bubba Watson          1,777
# ..     ...              ...            ...
# 252  27939   Matt McQuillan              2
# 253  06332   Neal Lancaster              2
# 254  02256       Tom Watson              2
# 255  12660  Jesper Parnevik              1
# 256  02214    Kirk Triplett              0
#
# [257 rows x 3 columns]
#        PID            PLAYER Top10Finishes
# 0    28237      Rory McIlroy            10
# 1    23623       Bo Van Pelt            10
# 2    30925    Dustin Johnson             9
# 3    23108       Matt Kuchar             9
# 4    08793       Tiger Woods             9
# ..     ...               ...           ...
# 177  21528    Henrik Stenson             1
# 178  26287   Roland Thatcher             1
# 179  30927      Brendon Todd             1
# 180  26497  Casey Wittenberg             1
# 181  31323     Gary Woodland             1
#
# [182 rows x 3 columns]
#        PID           PLAYER WorldRank
# 0    28237     Rory McIlroy     13.22
# 1    23983      Luke Donald      8.62
# 2    08793      Tiger Woods      8.53
# 3    22405      Justin Rose      6.42
# 4    24502       Adam Scott      6.21
# ..     ...              ...       ...
# 992  32505    Ryan Williams       .07
# 993  24219    Wes Heffernan       .07
# 994  28645  Kwanchai Tannin       .07
# 995  29192   Chris Campbell       .07
# 996  25101      Janne Mommo       .07
#
# [997 rows x 3 columns]
#        PID           PLAYER       Money
# 0    28237     Rory McIlroy  $8,047,952
# 1    08793      Tiger Woods  $6,133,158
# 2    27649  Brandt Snedeker  $4,989,739
# 3    25686     Jason Dufner  $4,869,304
# 4    25804     Bubba Watson  $4,644,997
# ..     ...              ...         ...
# 253  23048       Eric Axley      $7,215
# 254  01132      Mark Brooks      $7,215
# 255  01707     Steve Lowery      $7,215
# 256  20634     Peter Lonard      $7,210
# 257  02214    Kirk Triplett      $7,141
#
# [258 rows x 3 columns]
#        PID            PLAYER BirdieAvg
# 0    01810    Phil Mickelson      4.22
# 1    06527    Steve Stricker      4.13
# 2    23621    Rory Sabbatini      4.07
# 3    08793       Tiger Woods      4.07
# 4    26331  Charl Schwartzel      4.06
# ..     ...               ...       ...
# 175  32150  Michael Thompson      2.89
# 176  26497  Casey Wittenberg      2.84
# 177  26951    Johnson Wagner      2.83
# 178  22378   Trevor Immelman      2.81
# 179  32698       Bobby Gates      2.80
#
# [180 rows x 3 columns]
#        PID             PLAYER DrivingDistance
# 0    27129          Luke List           306.3
# 1    30925     Dustin Johnson           305.8
# 2    23452  Nicolas Colsaerts           305.7
# 3    31323      Gary Woodland           303.8
# 4    25804       Bubba Watson           303.7
# ..     ...                ...             ...
# 175  23800       Bryce Molder           273.8
# 176  08075        Jerry Kelly           273.2
# 177  20443           Jin Park           273.2
# 178  30711         Colt Knost           271.7
# 179  10423          Mike Weir           270.5
#
# [180 rows x 3 columns]
#        PID            PLAYER TotalDriving
# 0    27436     Graham DeLaet           53
# 1    33141    Keegan Bradley           72
# 2    21528    Henrik Stenson           73
# 3    22405       Justin Rose           79
# 4    31557        Jim Herman           82
# ..     ...               ...          ...
# 175  28310      Lee Williams          280
# 176  26951    Johnson Wagner          283
# 177  12782        Tim Herron          299
# 178  26497  Casey Wittenberg          308
# 179  10423         Mike Weir          343
#
# ...
# 194  23983        Luke Donald          326
# 195  32618       Rhein Gibson          331
#
# [196 rows x 3 columns]
#        PID             PLAYER   GIR%
# 0    22056      Cameron Percy  72.58
# 1    46970           Jon Rahm  71.93
# 2    31646    Emiliano Grillo  71.47
# 3    36871    Matthew NeSmith  71.09
# 4    48045  Michael Gellerman  70.80
# ..     ...                ...    ...
# 191  32139      Danny Willett  60.64
# 192  27141        J.B. Holmes  60.30
# 193  25632       Jimmy Walker  57.96
# 194  24781       Hunter Mahan  57.50
# 195  35617     Martin Trainer  55.46
#
# [196 rows x 3 columns]
#        PID              PLAYER Scrambling
# 0    35450     Patrick Cantlay      67.30
# 1    28252        Seamus Power      65.96
# 2    21961  Charles Howell III      65.86
# 3    25396            Kevin Na      65.12
# 4    29221        Webb Simpson      64.95
# ..     ...                 ...        ...
# 191  31557          Jim Herman      52.27
# 192  56278       Matthew Wolff      52.16
# 193  34264     Hudson Swafford      50.84
# 194  56762         Will Gordon      50.29
# 195  34213      Grayson Murray      46.67
#
# [196 rows x 3 columns]
#        PID              PLAYER SG_Total
# 0    46970            Jon Rahm    2.098
# 1    47959   Bryson DeChambeau    1.823
# 2    35450     Patrick Cantlay    1.820
# 3    26329    Louis Oosthuizen    1.599
# 4    48081   Xander Schauffele    1.484
# ..     ...                 ...      ...
# 191  34314  Sebastian Cappelen   -1.507
# 192  27974           Sung Kang   -1.520
# 193  35617      Martin Trainer   -1.781
# 194  24781        Hunter Mahan   -1.788
# 195  34213      Grayson Murray   -2.108
#
# [196 rows x 3 columns]
#        PID              PLAYER SG_ApproachGreen
# 0    50525     Collin Morikawa            1.170
# 1    25364          Paul Casey             .895
# 2    33448       Justin Thomas             .887
# 3    33141      Keegan Bradley             .856
# 4    40026       Daniel Berger             .834
# ..     ...                 ...              ...
# 191  35658        Kris Ventura            -.751
# 192  19846           Brian Gay            -.774
# 193  34314  Sebastian Cappelen            -.800
# 194  35617      Martin Trainer           -1.458
# 195  24781        Hunter Mahan           -1.601
#
# [196 rows x 3 columns]
#        PID             PLAYER SG_Putting
# 0    26329   Louis Oosthuizen       .764
# 1    49771        J.T. Poston       .706
# 2    24138        Ian Poulter       .695
# 3    34360       Patrick Reed       .669
# 4    24024       Zach Johnson       .667
# ..     ...                ...        ...
# 191  30110       Kyle Stanley      -.712
# 192  34255    Joseph Bramlett      -.724
# 193  48045  Michael Gellerman      -.771
# 194  33948      Byeong Hun An      -.867
# 195  34213     Grayson Murray     -1.261
#
# [196 rows x 3 columns]
#        PID             PLAYER SG_OffTee
# 0    47959  Bryson DeChambeau     1.162
# 1    46970           Jon Rahm      .834
# 2    21209      Sergio Garcia      .796
# 3    28237       Rory McIlroy      .660
# 4    46717     Viktor Hovland      .656
# ..     ...                ...       ...
# 191  28679       Fabián Gómez     -.706
# 192  23983        Luke Donald     -.805
# 193  32618       Rhein Gibson     -.891
# 194  24357          K.J. Choi     -.977
# 195  39975        Michael Kim    -1.247
#
# [196 rows x 3 columns]
#        PID              PLAYER SG_AroundGreen
# 0    25396            Kevin Na           .702
# 1    32139       Danny Willett           .518
# 2    28679        Fabián Gómez           .484
# 3    37455          Si Woo Kim           .467
# 4    28252        Seamus Power           .440
# ..     ...                 ...            ...
# 191  34213      Grayson Murray          -.522
# 192  35658        Kris Ventura          -.552
# 193  34314  Sebastian Cappelen          -.632
# 194  28420          Ryan Brehm          -.688
# 195  24781        Hunter Mahan          -.783
#
# [196 rows x 3 columns]
#        PID              PLAYER SG_TeeToGreen
# 0    46970            Jon Rahm         1.767
# 1    50525     Collin Morikawa         1.528
# 2    35450     Patrick Cantlay         1.418
# 3    33448       Justin Thomas         1.418
# 4    47959   Bryson DeChambeau         1.367
# ..     ...                 ...           ...
# 191  27974           Sung Kang        -1.426
# 192  34314  Sebastian Cappelen        -1.557
# 193  32618        Rhein Gibson        -1.758
# 194  35617      Martin Trainer        -2.057
# 195  24781        Hunter Mahan        -2.279
#
# [196 rows x 3 columns]
#        PID            PLAYER FedExCupPoints
# 0    50525   Collin Morikawa          2,171
# 1    34046     Jordan Spieth          2,139
# 2    35450   Patrick Cantlay          2,056
# 3    34099    Harris English          2,039
# 4    46970          Jon Rahm          2,003
# ..     ...               ...            ...
# 245  20157     Retief Goosen              3
# 246  21407       Arjun Atwal              3
# 247  40058         Zac Blair              3
# 248  08075       Jerry Kelly              3
# 249  24449  Parker McLachlin              2
#
# [250 rows x 3 columns]
#        PID             PLAYER Top10Finishes
# 0    46970           Jon Rahm            15
# 1    45526      Abraham Ancer             9
# 2    47959  Bryson DeChambeau             9
# 3    30925     Dustin Johnson             9
# 4    34046      Jordan Spieth             9
# ..     ...                ...           ...
# 176  37189  Harold Varner III             1
# 177  25632       Jimmy Walker             1
# 178  51894       Vince Whaley             1
# 179  29454   Bernd Wiesberger             1
# 180  52374         Brandon Wu             1
#
# [181 rows x 3 columns]
#        PID             PLAYER WorldRank
# 0    46970           Jon Rahm     10.69
# 1    30925     Dustin Johnson      8.82
# 2    50525    Collin Morikawa      8.27
# 3    35450    Patrick Cantlay      7.68
# 4    48081  Xander Schauffele      7.49
# ..     ...                ...       ...
# 994  59425        Trace Crowe       .08
# 995  20935     Toru Taniguchi       .08
# 996  49608        Leonard Bem       .08
# 997  48811          Tom Gandy       .08
# 998  48632   Yuto Katsuragawa       .08
#
# [999 rows x 3 columns]
#        PID             PLAYER       Money
# 0    46970           Jon Rahm  $7,705,933
# 1    35450    Patrick Cantlay  $7,638,805
# 2    47959  Bryson DeChambeau  $7,426,415
# 3    50525    Collin Morikawa  $7,059,908
# 4    33448      Justin Thomas  $6,537,153
# ..     ...                ...         ...
# 247  01381          Fred Funk      $9,000
# 248  21407        Arjun Atwal      $8,120
# 249  40058          Zac Blair      $8,120
# 250  20157      Retief Goosen      $6,810
# 251  24449   Parker McLachlin      $6,090
#
# [252 rows x 3 columns]
#        PID             PLAYER BirdieAvg
# 0    35891      Cameron Smith      4.63
# 1    46046  Scottie Scheffler      4.60
# 2    33448      Justin Thomas      4.58
# 3    28237       Rory McIlroy      4.53
# 4    35450    Patrick Cantlay      4.44
# ..     ...                ...       ...
# 188  31557         Jim Herman      3.22
# 189  19803        Ryan Armour      3.20
# 190  33490            Bo Hoag      3.20
# 191  39436       Joshua Creel      3.19
# 192  33597        Harry Higgs      3.15
#
# [193 rows x 3 columns]
#        PID         PLAYER DrivingDistance
# 0    52372  Cameron Champ           321.4
# 1    28237   Rory McIlroy           321.3
# 2    57366  Cameron Young           319.3
# 3    51766  Wyndham Clark           319.0
# 4    46970       Jon Rahm           318.9
# ..     ...            ...             ...
# 188  23325  Vaughn Taylor           284.7
# 189  39436   Joshua Creel           284.6
# 190  26476    Chez Reavie           283.9
# 191  30927   Brendon Todd           279.0
# 192  31560   Brian Stuard           277.4
#
# [193 rows x 3 columns]
#        PID             PLAYER TotalDriving
# 0    46970           Jon Rahm           61
# 1    39546     Keith Mitchell           91
# 2    48081  Xander Schauffele           95
# 3    39997      Corey Conners           98
# 4    39971         Sungjae Im           98
# ..     ...                ...          ...
# 188  29289           S.Y. Noh          295
# 189  27770    Camilo Villegas          295
# 190  24361          Pat Perez          297
# 191  48084       Wesley Bryan          299
# 192  23983        Luke Donald          323
#
# [193 rows x 3 columns]
#        PID             PLAYER   GIR%
# 0    46046  Scottie Scheffler  72.29
# 1    39997      Corey Conners  71.90
# 2    46970           Jon Rahm  71.59
# 3    33122       Russell Knox  71.41
# 4    29725         Tony Finau  71.25
# ..     ...                ...    ...
# 188  33597        Harry Higgs  61.39
# 189  48084       Wesley Bryan  61.00
# 190  39436       Joshua Creel  60.40
# 191  27895        Jonas Blixt  58.78
# 192  39058      Lucas Herbert  57.82
#
# [193 rows x 3 columns]
#        PID                   PLAYER Scrambling
# 0    40098         Matt Fitzpatrick      69.62
# 1    23108              Matt Kuchar      69.20
# 2    33204              Shane Lowry      67.46
# 3    45522  Christiaan Bezuidenhout      66.05
# 4    39971               Sungjae Im      66.02
# ..     ...                      ...        ...
# 188  20229             Stewart Cink      51.82
# 189  40006          Erik van Rooyen      51.66
# 190  37212              Paul Barjon      51.47
# 191  32366           Kevin Chappell      51.20
# 192  54421            Garrick Higgo      45.77
#
# [193 rows x 3 columns]
#        PID             PLAYER SG_Total
# 0    28237       Rory McIlroy    2.115
# 1    40098   Matt Fitzpatrick    1.792
# 2    47483     Will Zalatoris    1.767
# 3    33448      Justin Thomas    1.680
# 4    46046  Scottie Scheffler    1.677
# ..     ...                ...      ...
# 188  25686       Jason Dufner   -1.087
# 189  47128     Richy Werenski   -1.090
# 190  48084       Wesley Bryan   -1.125
# 191  35110      Brett Drewitt   -1.364
# 192  27895        Jonas Blixt   -1.374
#
# [193 rows x 3 columns]
#        PID             PLAYER SG_ApproachGreen
# 0    47483     Will Zalatoris            1.063
# 1    34098     Russell Henley             .969
# 2    50525    Collin Morikawa             .854
# 3    46046  Scottie Scheffler             .819
# 4    35891      Cameron Smith             .771
# ..     ...                ...              ...
# 188  32333         Kevin Tway            -.654
# 189  35461       Beau Hossler            -.666
# 190  35617     Martin Trainer            -.938
# 191  39058      Lucas Herbert            -.979
# 192  27895        Jonas Blixt           -1.352
#
# [193 rows x 3 columns]
#        PID           PLAYER SG_Putting
# 0    39058    Lucas Herbert       .853
# 1    47993   Denny McCarthy       .818
# 2    30927     Brendon Todd       .781
# 3    34363   Tyrrell Hatton       .742
# 4    35461     Beau Hossler       .717
# ..     ...              ...        ...
# 188  25900     Lucas Glover      -.568
# 189  27770  Camilo Villegas      -.611
# 190  25686     Jason Dufner      -.701
# 191  27129        Luke List      -.895
# 192  34255  Joseph Bramlett      -.951
#
# [193 rows x 3 columns]
#        PID          PLAYER SG_OffTee
# 0    46970        Jon Rahm     1.025
# 1    57366   Cameron Young      .914
# 2    28237    Rory McIlroy      .771
# 3    39546  Keith Mitchell      .761
# 4    39997   Corey Conners      .700
# ..     ...             ...       ...
# 188  35110   Brett Drewitt     -.726
# 189  27139    David Skinns     -.819
# 190  23983     Luke Donald     -.840
# 191  29289        S.Y. Noh    -1.137
# 192  48084    Wesley Bryan    -1.574
#
# [193 rows x 3 columns]
#        PID           PLAYER SG_AroundGreen
# 0    23108      Matt Kuchar           .519
# 1    32139    Danny Willett           .513
# 2    46402      Talor Gooch           .502
# 3    26300       Matt Jones           .480
# 4    30911  Tommy Fleetwood           .467
# ..     ...              ...            ...
# 188  45526    Abraham Ancer          -.447
# 189  40006  Erik van Rooyen          -.460
# 190  46717   Viktor Hovland          -.651
# 191  37212      Paul Barjon          -.740
# 192  34264  Hudson Swafford          -.747
#
# [193 rows x 3 columns]
#        PID             PLAYER SG_TeeToGreen
# 0    47483     Will Zalatoris         1.770
# 1    28237       Rory McIlroy         1.619
# 2    33448      Justin Thomas         1.589
# 3    46046  Scottie Scheffler         1.475
# 4    29725         Tony Finau         1.408
# ..     ...                ...           ...
# 188  39058      Lucas Herbert        -1.132
# 189  48084       Wesley Bryan        -1.141
# 190  47128     Richy Werenski        -1.339
# 191  35617     Martin Trainer        -1.405
# 192  27895        Jonas Blixt        -1.610
#
# [193 rows x 3 columns]
#        PID             PLAYER FedExCupPoints
# 0    46046  Scottie Scheffler          3,556
# 1    35891      Cameron Smith          2,335
# 2    47504          Sam Burns          2,275
# 3    48081  Xander Schauffele          2,153
# 4    35450    Patrick Cantlay          2,108
# ..     ...                ...            ...
# 242  01457           Jay Haas              3
# 243  21753        Brian Davis              3
# 244  26679      Kevin Stadler              2
# 245  21350        Ryuji Imada              2
# 246  28307         Matt Every              2
#
# [247 rows x 3 columns]
#        PID             PLAYER Top10Finishes
# 0    35450    Patrick Cantlay            12
# 1    46046  Scottie Scheffler            11
# 2    40098   Matt Fitzpatrick            10
# 3    28237       Rory McIlroy            10
# 4    33448      Justin Thomas            10
# ..     ...                ...           ...
# 189  27095        Nick Watney             1
# 190  25804       Bubba Watson             1
# 191  32139      Danny Willett             1
# 192  54783           Dylan Wu             1
# 193  45242           Kevin Yu             1
#
# [194 rows x 3 columns]
#        PID               PLAYER WorldRank
# 0    46046    Scottie Scheffler      9.94
# 1    28237         Rory McIlroy      9.07
# 2    35891        Cameron Smith      8.92
# 3    35450      Patrick Cantlay      8.32
# 4    48081    Xander Schauffele      7.34
# ..     ...                  ...       ...
# 993  49533  James Hart du Preez       .10
# 994  56320        Bryson Nimmer       .10
# 995  55080          Ruth Tobias       .10
# 996  39914       Hampus Bergman       .10
# 997  63458     Chisato Takamiya       .10
#
# [998 rows x 3 columns]
#        PID             PLAYER        Money
# 0    46046  Scottie Scheffler  $14,046,910
# 1    35891      Cameron Smith  $10,107,897
# 2    47483     Will Zalatoris   $9,405,082
# 3    35450    Patrick Cantlay   $9,369,605
# 4    28237       Rory McIlroy   $8,654,566
# ..     ...                ...          ...
# 242  08385        Omar Uresti      $14,910
# 243  20645        John Senden      $13,650
# 244  21753        Brian Davis       $8,177
# 245  26679      Kevin Stadler       $7,955
# 246  28307         Matt Every       $7,659
#
# [247 rows x 3 columns]
#      PID          PLAYER ScoringAvg BirdieAvg DrivingDistance TotalDriving  \
# 0  08793     Tiger Woods     67.794      4.03           302.4          164
# 1  06522       Ernie Els     69.294      3.64           297.9          210
# 2  22405     Justin Rose     69.301      3.81           288.7          191
# 3  06527  Steve Stricker     69.394      3.61           283.7          243
# 4  01810  Phil Mickelson     69.456      3.70           298.1          210
#
#     GIR% Scrambling SG_Total SG_ApproachGreen  ... SG_OffTee SG_AroundGreen  \
# 0  71.02      61.02    3.092            1.653  ...      .624           .103
# 1  64.66      60.16    1.578             .994  ...      .452           .163
# 2  65.73      59.89     .878             .404  ...      .157           .255
# 3  65.83      60.98    1.486             .811  ...      .002           .351
# 4  64.95      59.15    1.597             .614  ...      .328           .499
#
#   SG_TeeToGreen FedExCupPoints Top10Finishes WorldRank        Money  Year  \
# 0         2.380         30,574            12     20.40  $10,867,052  2007
# 1         1.609          8,980             5      6.60   $2,705,715  2007
# 2          .816          8,698             7      6.02   $2,705,875  2007
# 3         1.164         10,621             9      6.65   $4,663,077  2007
# 4         1.441         16,037             7      9.04   $5,819,988  2007
#
#    Country #Wins
# 0      USA     2
# 1      RSA     -
# 2      ENG     -
# 3      USA     1
# 4      USA     1
#
# [5 rows x 21 columns]

# %%
# Change empty values to a 0, this will allow conversion to integer
combined_df["#Wins"] = combined_df["#Wins"].replace("-",0)
combined_df.head()
# Out:
#      PID          PLAYER ScoringAvg BirdieAvg DrivingDistance TotalDriving  \
# 0  08793     Tiger Woods     67.794      4.03           302.4          164
# 1  06522       Ernie Els     69.294      3.64           297.9          210
# 2  22405     Justin Rose     69.301      3.81           288.7          191
# 3  06527  Steve Stricker     69.394      3.61           283.7          243
# 4  01810  Phil Mickelson     69.456      3.70           298.1          210
#
#     GIR% Scrambling SG_Total SG_ApproachGreen  ... SG_OffTee SG_AroundGreen  \
# 0  71.02      61.02    3.092            1.653  ...      .624           .103
# 1  64.66      60.16    1.578             .994  ...      .452           .163
# 2  65.73      59.89     .878             .404  ...      .157           .255
# 3  65.83      60.98    1.486             .811  ...      .002           .351
# 4  64.95      59.15    1.597             .614  ...      .328           .499
#
#   SG_TeeToGreen FedExCupPoints Top10Finishes WorldRank        Money  Year  \
# 0         2.380         30,574            12     20.40  $10,867,052  2007
# 1         1.609          8,980             5      6.60   $2,705,715  2007
# 2          .816          8,698             7      6.02   $2,705,875  2007
# 3         1.164         10,621             9      6.65   $4,663,077  2007
# 4         1.441         16,037             7      9.04   $5,819,988  2007
#
#    Country #Wins
# 0      USA     2
# 1      RSA     0
# 2      ENG     0
# 3      USA     1
# 4      USA     1
#
# [5 rows x 21 columns]

# %%
# Update all data types

combined_df['PLAYER'] = combined_df['PLAYER'].astype(object)
combined_df['ScoringAvg'] = combined_df['ScoringAvg'].astype(float)
combined_df['BirdieAvg'] = combined_df['BirdieAvg'].astype(float)
combined_df['DrivingDistance'] = combined_df['DrivingDistance'].astype(float)
combined_df['TotalDriving'] = combined_df['TotalDriving'].astype(float)
combined_df['GIR%'] = combined_df['GIR%'].astype(float)
combined_df['Scrambling'] = combined_df['Scrambling'].astype(float)
combined_df['SG_Total'] = combined_df['SG_Total'].astype(float)
combined_df['SG_ApproachGreen'] = combined_df['SG_ApproachGreen'].astype(float)
combined_df['SG_Putting'] = combined_df['SG_Putting'].astype(float)
combined_df['SG_OffTee'] = combined_df['SG_OffTee'].astype(float)
combined_df['SG_AroundGreen'] = combined_df['SG_AroundGreen'].astype(float)
combined_df['SG_TeeToGreen'] = combined_df['SG_TeeToGreen'].astype(float)
combined_df['FedExCupPoints'] = combined_df['FedExCupPoints'].str.replace(',', '',regex=True).astype(int)
combined_df['Top10Finishes'] = combined_df['Top10Finishes'].astype(int)
combined_df['WorldRank'] = combined_df['WorldRank'].astype(float)
combined_df['Money'] = combined_df['Money'].str.replace('[$,]', '',regex=True).astype(int)
combined_df['#Wins'] = combined_df['#Wins'].astype(int)

combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2353 entries, 0 to 2352
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PID               2353 non-null   object
#  1   PLAYER            2353 non-null   object
#  2   ScoringAvg        2353 non-null   float64
#  3   BirdieAvg         2353 non-null   float64
#  4   DrivingDistance   2353 non-null   float64
#  5   TotalDriving      2353 non-null   float64
#  6   GIR%              2353 non-null   float64
#  7   Scrambling        2353 non-null   float64
#  8   SG_Total          2353 non-null   float64
#  9   SG_ApproachGreen  2353 non-null   float64
#  10  SG_Putting        2353 non-null   float64
#  11  SG_OffTee         2353 non-null   float64
#  12  SG_AroundGreen    2353 non-null   float64
#  13  SG_TeeToGreen     2353 non-null   float64
#  14  FedExCupPoints    2353 non-null   int64
#  15  Top10Finishes     2353 non-null   int64
#  16  WorldRank         2353 non-null   float64
#  17  Money             2353 non-null   int64
#  18  Year              2353 non-null   int64
#  19  Country           2353 non-null   object
#  20  #Wins             2353 non-null   int64
# dtypes: float64(13), int64(5), object(3)
# memory usage: 386.2+ KB

# %%
# Reorder the columns to make more sense
order = ['PLAYER','Country','Year','ScoringAvg','BirdieAvg','DrivingDistance','TotalDriving',
         'GIR%','Scrambling','SG_Total','SG_ApproachGreen','SG_Putting','SG_OffTee','SG_AroundGreen',
         'SG_TeeToGreen','Top10Finishes','#Wins','FedExCupPoints','WorldRank','Money']
combined_df = combined_df[order]
combined_df.head()
# Out:
#            PLAYER Country  Year  ScoringAvg  BirdieAvg  DrivingDistance  \
# 0     Tiger Woods     USA  2007      67.794       4.03            302.4
# 1       Ernie Els     RSA  2007      69.294       3.64            297.9
# 2     Justin Rose     ENG  2007      69.301       3.81            288.7
# 3  Steve Stricker     USA  2007      69.394       3.61            283.7
# 4  Phil Mickelson     USA  2007      69.456       3.70            298.1
#
#    TotalDriving   GIR%  Scrambling  SG_Total  SG_ApproachGreen  SG_Putting  \
# 0         164.0  71.02       61.02     3.092             1.653       0.712
# 1         210.0  64.66       60.16     1.578             0.994      -0.031
# 2         191.0  65.73       59.89     0.878             0.404       0.061
# 3         243.0  65.83       60.98     1.486             0.811       0.322
# 4         210.0  64.95       59.15     1.597             0.614       0.156
#
#    SG_OffTee  SG_AroundGreen  SG_TeeToGreen  Top10Finishes  #Wins  \
# 0      0.624           0.103          2.380             12      2
# 1      0.452           0.163          1.609              5      0
# 2      0.157           0.255          0.816              7      0
# 3      0.002           0.351          1.164              9      1
# 4      0.328           0.499          1.441              7      1
#
#    FedExCupPoints  WorldRank     Money
# 0           30574      20.40  10867052
# 1            8980       6.60   2705715
# 2            8698       6.02   2705875
# 3           10621       6.65   4663077
# 4           16037       9.04   5819988

# %%
# Save the final data frame to a csv to use later

path = 'pga_full.csv'

combined_df.to_csv(path,index=False)

# %%
duplicate_rows = df.duplicated(subset=["PLAYER", "Country", "Year"], keep=False).any()
print(duplicate_rows)
# Out:
# False

# %% [markdown]
# ## Data Dictionary:
# Here is a brief description of the columns in the dataset:
#
# | Column Name         | Description                                                                 |
# |---------------------|-----------------------------------------------------------------------------|
# | PLAYER              | The name of the player.                                                     |
# | Country             | The player's home country                                                   |
# | Year                | The year in which the data is recorded.                                      |
# | ScoringAvg          | The average score of the player.                                             |
# | BirdieAvg           | The average number of birdies made by the player per round.                            |
# | DrivingDistance     | The average distance of the player's drives.                                 |
# | TotalDriving        | The player's total driving score.                                         |
# | GIR%                | The percentage of greens in regulation (GIR) achieved by the player.         |
# | Scrambling          | The player's scrambling rate, indicating the ability to recover from difficult positions.|
# | SG_Total            | The player's strokes gained total.                                           |
# | SG_ApproachGreen    | The player's strokes gained on approach shots to the green.                  |
# | SG_Putting          | The player's strokes gained through putting.                                 |
# | SG_OffTee           | The player's strokes gained off the tee.                                     |
# | SG_AroundGreen      | The player's strokes gained around the green.                                |
# | SG_TeeToGreen       | The player's strokes gained from tee to green.                               |
# | Top10Finishes       | The number of top 10 finishes achieved by the player.                        |
# | #Wins               | The number of wins achieved by the player.                                   |
# | FedExCupPoints      | The player's total FedEx Cup points.                                         |
# | WorldRank           | The player's average points, where higher points indicate a higher world rank.|
# | Money               | The amount of money earned by the player.                                    |
